# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit130198/Python/blob/main/Assignment_2_input()_Function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input('What is your Name: ')
print(f'Welcome to Python World', name)

age = input('What is your Age: ')
print('Help me with your Location Details')
city = input('City: ')
state = input('State: ')

print('Thank you for sharing the location, could you please help me with your Educational Background')

college_name = input('Collage Name: ')
Branch = input('Branch: ')
Semester = input('Semester Details: ')

print('Perfecto, moving ahead please help me with your favorite movie and actor')

Movie = input('Enter your Favorite Movie Name: ')
Actor = input('Enter your Favorite Actor Name: ')

print("Tell me your favorite Movie's Max Box Office Collection and Age of your favorite Actor")

Collection = int(input('Box Office Collection: '))
Actor_Age = int(input("Actor's Age: "))

print("Alright we are good so far, can I have your parent's details")

Father_Name = input("Enter Your Father's Name: ")
Mother_Name = input("Enter you Mother's Name: ")

print("What is your Phone Number and Email Id")

Ph_No = int(input("Enter your Phone Number: "))
Email_ID = input("Enter you Email ID: ")

print("Thank you so much for the details, could you please help me with your official details")

Office_name = input("Enter your Company Name: ")
designation = input("Enter your Designation: ")

print("Awesome! You Official Location Details?" )

Official_Country = input("Country: ")
Official_State = input("State: ")
Official_City = input("City: ")
Official_Pin_code = int(input("Pincode: "))

print("Thank You for your Paitence, Have a Good One")
# Out:
# What is your Name: w
# Welcome to Python World w
# What is your Age: 12
# Help me with your Location Details
# City: 2
# State: d
# Thank you for sharing the location, could you please help me with your Educational Background
# Collage Name: d
# Branch: d
# Semester Details: d
# Perfecto, moving ahead please help me with your favorite movie and actor
# Enter your Favorite Movie Name: d
# Enter your Favorite Actor Name: d
# Tell me your favorite Movie's Max Box Office Collection and Age of your favorite Actor
# Box Office Collection: 3
# Actor's Age: 3
# Alright we are good so far, can I have your parent's details
# Enter Your Father's Name: c
# Enter you Mother's Name: c
# What is your Phone Number and Email Id
# Enter your Phone Number: 33
# Enter you Email ID: c
# Thank you so much for the details, could you please help me with your official details
# Enter your Company Name: c
# Enter your Designation: c
# Awesome! You Official Location Details?
# Country: c
# State: c
# City: c
# ...
