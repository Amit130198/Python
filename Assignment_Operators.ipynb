# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit130198/Python/blob/main/Assignment_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 25
b = 5

print (a + b) #Addition
print (a - b) #Subtraction
print (a * b) #Multiplication
print (a / b) #Division
print (a % b) #Modulus
print (a ** b) #Exponent
print (a // b) #Floor Division
# Out:
# 30
# 20
# 125
# 5.0
# 0
# 9765625
# 5

# %%
#Question 2

user_a = int(input('Enter your Number'))
user_b = int(input('Enter your Number'))

Addition = print (user_a + user_b)
Subtraction = print (user_a - user_b)
Multiplication = print (user_a * user_b)
Division = print (user_a / user_b)
# Out:
# Enter your Number2
# Enter your Number2
# 4
# 0
# 4
# 1.0

# %%
#Question 3
Friend_one = int(input('Enter Your Age: '))
Friend_two = int(input('Enter Your Age: '))

Total_age = print(Friend_one + Friend_two)
Difference_of_ages = print(Friend_one - Friend_two)
Alternative_Difference_of_ages = print(abs(Friend_one - Friend_two)) #absolute value
Product_of_ages = print(Friend_one * Friend_two)
# Out:
# Enter Your Age: 10
# Enter Your Age: 19
# 29
# -9
# 9
# 190

# %%
#Question 4

Product_A = int(input('Price of the Product: '))
Product_B = int(input('Price of the Product: '))

Total_bill = print(f'Grand Total:', Product_A + Product_B)
Difference = print(f'Price Difference:', abs(Product_A - Product_B))
Product_of_prices = print(Product_A * Product_B)
# Out:
# Price of the Product: 10
# Price of the Product: 100
# Grand Total: 110
# Price Difference: 90
# 1000

# %%
#Question 5
x = int(input('Enter Your Number: '))
y = int(input('Enter Your Number: '))

print(x + y)
print (x - y)
print (x * y)
print(x / y)
print(x // y)
print(x % y)
print(x ** y)
# Out:
# Enter Your Number: 10
# Enter Your Number: 5
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
#Question 6
#Area = Length × Width
#Perimeter = 2 × (Length + Width)

Length = int(input('Enter the Length of the Rectagle: '))
Breadth = int(input('Enter the Breadth of the Rectagle: '))


Area = print(f'Area of the Rectangle is', Length * Breadth)
Perimeter = print(f'Perimeter of the Rectangle is', 2* (Length + Breadth))
# Out:
# Enter the Length of the Rectagle: 10
# Enter the Breadth of the Rectagle: 5
# Area of the Rectangle is 50
# Perimeter of the Rectangle is 30

# %%
#Question 7
#skip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_567/3084070543.py in <cell line: 0>()
#       1 #Question 7
# ----> 2 skip
#
# NameError: name 'skip' is not defined

# %%
from ast import MatchSequence
#Question 8
# Take three subject marks from the user and calculate:

#  . Total Marks
#  . Average Marks


Maths = int(input('Enter Subject Marks: '))
English = int(input('Enter Subject Marks: '))
Science = int(input('Enter Subject Marks: '))

Total_Marks = Maths + English + Science
print(f"Total Marks", Total_Marks)

Average_Marks = print(f'Average Marks', Total_Marks/3)
# Out:
# Enter Subject Marks: 10
# Enter Subject Marks: 56
# Enter Subject Marks: 32
# Total Marks 98
# Average Marks 32.666666666666664

# %%
# Question 9
# salary = 45000
# bonus = 5000

# Calculate:
#  . Total Salary
#  . Salary after deducting ₹2000

Emp_salary = 45000
Bonus = 5000

Total_Salary = Emp_salary + Bonus
print(Total_Salary)

Deduction = Total_Salary - 2000
print(Deduction)
# Out:
# 50000
# 48000

# %%
#Take the quantity and price of an item from the user. Calculate the total amount.

#Product >> Protein_Powder
Price =  5000

Quantity = int(input('Enter the Quantity: '))
print(Quantity * Price)
# Out:
# Enter the Quantity: 10
# 50000
