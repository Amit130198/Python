# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit130198/Python/blob/main/Assignment_3_format().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 1 and Question 2
#My name is Hitesh and I am 24 years old.

Name = input("Name: ")
Age = int(input("Age: "))
City = input("City: ")

print(f"My name is {Name} I'm {Age} years old and I stay in {City} ")
# Out:
# Name: Amit
# Age: 29
# City: Pune
# My name is Amit I'm 29 years old and I stay in Pune

# %%
#Question 3

Product = "Protein"
Price = 5500

print(f"XYZ mall has {Product} only @{Price}")
# Out:
# XYZ mall has Protein only @5500

# %%
#question 4
a = int(input("a: "))
b = int(input("b: "))
c = 50
if a + b == c:
  print(f"Sum of {a} and {b} is 50")
else:
  print(f"Sum of {a} and {b} is not 50")
# Out:
# a: 24
# b: 42
# Sum of 24 and 42 is not 50

# %%
#Question 5
#Take your college name and branch and display them using `format()`.

College_Name = "Pune university"
Branch = "Analytical"
sub_1 = int(input("Enter your marks:"))
sub_2 = int(input("Enter your marks:"))
sub_3 = int(input("Enter your marks:"))

print(f"My college is {College_Name}, pursuing my Master in {Branch}")
print (f"Sharing my last semester's marks")
print(f"sub_1", sub_1)
print(f"sub_1", sub_2)
print(f"sub_1", sub_3)

# print (f"Sharing my last semester's marks {sub_2}")
# print (f"Sharing my last semester's marks {sub_3}")
# Out:
# Enter your marks: 87
# Enter your marks:87
# Enter your marks:87
# My college is Pune university, pursuing my Master in Analytical
# Sharing my last semester's marks
# sub_1 87
# sub_1 87
# sub_1 87

# %%
#   . Q7.

# Take employee ID, employee name, and salary and print them using `format()`.

Emp_ID = int(input("Enter Your Emp_ID: "))
Emp_name = (input("Enter Your Name: "))
salary = int(input("Enter Your Salary: "))

print(f"My Name and Employee ID is {Emp_name} and {Emp_ID} as per my designation my monthly salary is {salary}")
# Out:
# Enter Your Emp_ID: 12
# Enter Your Name: a
# Enter Your Salary: 2000000
# My Name and Employee ID is a and 12 as per my designation my monthly salary is 2000000

# %%
#Question 8

Length = int(input("Lenghth Details: "))
Breadth = int(input("Breadth Details: "))
Area = Length * Breadth

print(f"Length of the Box is {Length} and it has perfect Breadth of {Breadth} which gives overall area {Area}")
# Out:
# Lenghth Details: 24
# Breadth Details: 23
# Length of the Box is 24 and it has perfect Breadth of 23 which gives overall area 552
