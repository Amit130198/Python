# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit130198/Python/blob/main/Assignment_6_Modulus_(_)_Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 1

Number_A = int(input("Enter Number: "))
Number_B = int(input("Enter Number: "))
print(Number_A % Number_B)
# Out:
# Enter Number: 10
# Enter Number: 3
# 1

# %%
#Question 2
a = 50
b = 7
print(a%b)
# Out:
# 1

# %%
#Question3
Chocolate = int(input("Enter Number of Chocolates:"))
Student = int(input("Enter Number of Students:"))

print(Chocolate % Student)
# Out:
# Enter Number of Chocolates:20
# Enter Number of Students:10
# 0

# %%
#Question 4
Total = 1000
Note = 200

print( Note % Total )
# Out:
# 200

# %%
#Question 5
x = 123
y = 10
print (x % y)
# Out:
# 3
