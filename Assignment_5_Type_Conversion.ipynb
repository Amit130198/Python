# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit130198/Python/blob/main/Assignment_5_Type_Conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Question 1
Covert = int(input("Enter the Number"))
print(type(Covert))
# Out:
# Enter the Number10
# <class 'int'>

# %%
#question 3
num = 25
print(type(num))

Float = float(num)
print(f" I'm Float {Float}")
print(type(Float))

String_num = str(num)
print(f"I'm String {String_num}")
print(type(String_num))
# Out:
# <class 'int'>
#  I'm Float 25.0
# <class 'float'>
# I'm String 25
# <class 'str'>

# %%
# Q4.
# Convert: price = "4999"
#into an integer and print its type.

price = int(4999)
print(type(price))
# Out:
# <class 'int'>

# %%
#Question 5
# Convert:
# marks = "89.5"
# into a float and print the result.

marks = float(89.5)
print(type(marks))
# Out:
# <class 'float'>

# %%
#Question 6
#Salary = 50000
Salary = str(50000)
print(Salary)
print(type(Salary))
# Out:
# 50000
# <class 'str'>

# %%
#Question 7

num = 45
print(type(num))

Float = float(num)
print(f" I'm Float {Float}")
print(type(Float))

String_num = str(num)
print(f"I'm String {String_num}")
print(type(String_num))
# Out:
# <class 'int'>
#  I'm Float 45.0
# <class 'float'>
# I'm String 45
# <class 'str'>

# %%
#Question 8
Age = int(input("Enter Your Age: "))
Add_Years = 5
Your_Age = Age + Add_Years
print(f"My age is {Your_Age}")
# Out:
# Enter Your Age: 10
# My age is 15

# %%
#Question 9
Product_A = float(input("Enter Your Product Name: "))
Product_B = float(input("Enter Your Product Name: "))
Final_Price = Product_A + Product_B

print(f"Grand Total of product is {Final_Price}")
print(type(Final_Price))
# Out:
# Enter Your Product Name: 20
# Enter Your Product Name: 239
# Grand Total of product is 259.0
# <class 'float'>

# %%
#Question 10

num = 75.9
print(type(num))

Integer_Type = int(num)
print(f" I'm Integer {Integer_Type}")
print(type(Integer_Type))

String_num = str(num)
print(f"I'm String {String_num}")
print(type(String_num))
# Out:
# <class 'float'>
#  I'm Integer 75
# <class 'int'>
# I'm String 75.9
# <class 'str'>
